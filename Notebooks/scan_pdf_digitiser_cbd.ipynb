# %%
import pytesseract
from pytesseract import Output
from pdf2image import convert_from_path
import glob
import random
import pandas
import json
import cv2
import numpy
import matplotlib.pyplot as plt
from utils import display_image_in_actual_size

# %%
images = glob.glob("temp/*")

# %%
image = cv2.imread(images[0])
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display_image_in_actual_size(image)

# %%
osd_op = pytesseract.image_to_osd(images[0], config = '--oem 0 --psm 0 --dpi 70 -l eng', output_type=Output.DICT, lang='eng')
# Out:
# ---------------------------------------------------------------------------
# TesseractError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 osd_op = pytesseract.image_to_osd(images[0], config = '--oem 0 --psm 0 --dpi 70 -l eng', output_type=Output.DICT, lang='eng')
#
# File ~/Documents/Table-ai/table-ai/lib/python3.9/site-packages/pytesseract/pytesseract.py:545, in image_to_osd(image, lang, config, nice, output_type, timeout)
#     542 config = f'--psm 0 {config.strip()}'
#     543 args = [image, 'osd', lang, config, nice, timeout]
# --> 545 return {
#     546     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     547     Output.DICT: lambda: osd_to_dict(run_and_get_output(*args)),
#     548     Output.STRING: lambda: run_and_get_output(*args),
#     549 }[output_type]()
#
# File ~/Documents/Table-ai/table-ai/lib/python3.9/site-packages/pytesseract/pytesseract.py:547, in image_to_osd.<locals>.<lambda>()
# ...

# %%
# Out:
# '/Users/devanshisukhija/Documents/Artivatic/MedBills-Tariff/R&D/Notebooks/temp/HS00067837-Rate Listpage1.jpg'
